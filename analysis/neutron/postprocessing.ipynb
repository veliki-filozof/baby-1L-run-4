# %% [markdown]
# # LIBRA and the Liquid Immersion Blanket
# ## 1L BABY
# - Wall permeation
# - FLiBe handing (ClLiF)
# - Wall materials
# - Tritium probe

# %%
import math
import openmc
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, ListedColormap
from openmc_model import baby_model

# %% [markdown]
# ### Geometry

# %%
model = baby_model()
geometry = model.geometry
# Out:
# isotopes ['Al27', 'Ar36', 'Ar38', 'Ar40', 'B10', 'B11', 'Be9', 'C12', 'C13', 'Ca40', 'Ca42', 'Ca43', 'Ca44', 'Ca46', 'Ca48', 'Cl35', 'Cl37', 'Co59', 'Cr50', 'Cr52', 'Cr53', 'Cr54', 'Cu63', 'Cu65', 'F19', 'Fe54', 'Fe56', 'Fe57', 'Fe58', 'H1', 'H2', 'He3', 'He4', 'K39', 'K40', 'K41', 'Li6', 'Li7', 'Mg24', 'Mg25', 'Mg26', 'Mn55', 'Mo100', 'Mo92', 'Mo94', 'Mo95', 'Mo96', 'Mo97', 'Mo98', 'N14', 'N15', 'Na23', 'Nb93', 'Ni58', 'Ni60', 'Ni61', 'Ni62', 'Ni64', 'O16', 'O17', 'O18', 'P31', 'Pb204', 'Pb206', 'Pb207', 'Pb208', 'S32', 'S33', 'S34', 'S36', 'Si28', 'Si29', 'Si30', 'Ti46', 'Ti47', 'Ti48', 'Ti49', 'Ti50', 'W182', 'W183', 'W184', 'W186', 'Zr90', 'Zr91', 'Zr92', 'Zr94', 'Zr96']
# Searching libraries with the following priority {'ENDFB-8.0-NNDC': 1}
# Isotopes found matching library requirements 556
# Isotopes found matching particle requirements 1789
# Isotopes found matching isotope requirements 345
# Isotopes found matching all requirements 87
#              library remote_file  \
# 1233  ENDFB-8.0-NNDC       H1.h5
# 1234  ENDFB-8.0-NNDC       H2.h5
# 1236  ENDFB-8.0-NNDC      He3.h5
# 1237  ENDFB-8.0-NNDC      He4.h5
# 1238  ENDFB-8.0-NNDC      Li6.h5
# ...              ...         ...
# 1649  ENDFB-8.0-NNDC     W186.h5
# 1689  ENDFB-8.0-NNDC    Pb204.h5
# 1691  ENDFB-8.0-NNDC    Pb206.h5
# 1692  ENDFB-8.0-NNDC    Pb207.h5
# 1693  ENDFB-8.0-NNDC    Pb208.h5
#
#                                                     url  \
# 1233  https://github.com/openmc-data-storage/ENDF-B-...
# 1234  https://github.com/openmc-data-storage/ENDF-B-...
# 1236  https://github.com/openmc-data-storage/ENDF-B-...
# 1237  https://github.com/openmc-data-storage/ENDF-B-...
# 1238  https://github.com/openmc-data-storage/ENDF-B-...
# ...                                                 ...
# 1649  https://github.com/openmc-data-storage/ENDF-B-...
# 1689  https://github.com/openmc-data-storage/ENDF-B-...
# 1691  https://github.com/openmc-data-storage/ENDF-B-...
# 1692  https://github.com/openmc-data-storage/ENDF-B-...
# 1693  https://github.com/openmc-data-storage/ENDF-B-...
#
#                    local_file particle isotope element  priority
# 1233     ENDFB-8.0-NNDC_H1.h5  neutron      H1       H         1
# 1234     ENDFB-8.0-NNDC_H2.h5  neutron      H2       H         1
# 1236    ENDFB-8.0-NNDC_He3.h5  neutron     He3      He         1
# 1237    ENDFB-8.0-NNDC_He4.h5  neutron     He4      He         1
# 1238    ENDFB-8.0-NNDC_Li6.h5  neutron     Li6      Li         1
# ...                       ...      ...     ...     ...       ...
# 1649   ENDFB-8.0-NNDC_W186.h5  neutron    W186       W         1
# 1689  ENDFB-8.0-NNDC_Pb204.h5  neutron   Pb204      Pb         1
# 1691  ENDFB-8.0-NNDC_Pb206.h5  neutron   Pb206      Pb         1
# 1692  ENDFB-8.0-NNDC_Pb207.h5  neutron   Pb207      Pb         1
# 1693  ENDFB-8.0-NNDC_Pb208.h5  neutron   Pb208      Pb         1
#
# [87 rows x 8 columns]
# Skipping ENDFB-8.0-NNDC_H1.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_H2.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_He3.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_He4.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Li6.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Li7.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Be9.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_B10.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_B11.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_C12.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_C13.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_N14.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_N15.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_O16.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_O17.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_O18.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_F19.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Na23.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mg24.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mg25.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mg26.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Al27.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Si28.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Si29.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Si30.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_P31.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_S32.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_S33.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_S34.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_S36.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Cl35.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Cl37.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ar36.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ar38.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ar40.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_K39.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_K40.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_K41.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ca40.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ca42.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ca43.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ca44.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ca46.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ca48.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ti46.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ti47.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ti48.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ti49.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ti50.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Cr50.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Cr52.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Cr53.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Cr54.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mn55.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Fe54.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Fe56.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Fe57.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Fe58.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Co59.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ni58.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ni60.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ni61.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ni62.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Ni64.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Cu63.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Cu65.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Zr90.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Zr91.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Zr92.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Zr94.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Zr96.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Nb93.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mo92.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mo94.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mo95.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mo96.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mo97.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mo98.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Mo100.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_W182.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_W183.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_W184.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_W186.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Pb204.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Pb206.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Pb207.h5, already downloaded
# Skipping ENDFB-8.0-NNDC_Pb208.h5, already downloaded
# written cross sections xml file to /home/remidm/BABY-1L-run-1/analysis/neutron/cross_sections.xml
# setting OPENMC_CROSS_SECTIONS to /home/remidm/BABY-1L-run-1/analysis/neutron/cross_sections.xml
# /home/remidm/miniconda3/envs/baby_1l_run_1/lib/python3.12/site-packages/openmc/source.py:656: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)

# %%
# Visualization

from vault import Air
from openmc_model import air

x_c = 587
y_c = 60
z_c = 100
ax = geometry.plot(
    width=(2500, 1500),
    origin=(x_c, y_c, z_c + 10),
    pixels=(1000, 1000),
    basis="xy",
    color_by="material",
    colors={Air: "white", air: "white"},
)
ax.tick_params(axis="both", labelsize=20)
ax.set_xlabel(ax.get_xlabel(), fontsize=20)
ax.set_ylabel(ax.get_ylabel(), fontsize=20)
plt.show()

# %%
ax = geometry.plot(
    width=(85, 85),
    origin=(x_c, y_c, z_c + 10),
    pixels=(1000, 1000),
    basis="xz",
    color_by="material",
    colors={Air: "white", air: "white"},
)
ax.tick_params(axis="both", labelsize=20)
ax.set_xlabel(ax.get_xlabel(), fontsize=20)
ax.set_ylabel(ax.get_ylabel(), fontsize=20)
plt.show()

# %% [markdown]
# ### Result

# %%
sp = openmc.StatePoint("statepoint.100.h5")
tbr_withvault = sp.get_tally(name="TBR").get_pandas_dataframe()
print(f"TBR: {tbr_withvault['mean'].iloc[0] :.6e}\n")
print(f"TBR std. dev.: {tbr_withvault['std. dev.'].iloc[0] :.6e}\n")
# Out:
# TBR: 2.041907e-03
#
# TBR std. dev.: 2.790358e-05
